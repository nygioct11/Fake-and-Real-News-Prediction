# %% [markdown]
# **CODXO INTERNSHIP**
#
# TASK 1: Fake News Detection
#
# AUTHOR: Nessy Dsouza
#
# DOMAIN : Data Science

# %% [markdown]
# Import Necessary Libraries

# %%
import pandas as pd
import numpy as np
from nltk.stem import SnowballStemmer
from nltk.tokenize import word_tokenize
import nltk
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# Loading the dataset

# %%
true=pd.read_csv("/content/drive/MyDrive/fake and real news/true.csv",encoding="ISO-8859-1")
true
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# ...

# %%
fake=pd.read_csv("/content/drive/MyDrive/fake and real news/fake.csv",encoding="ISO-8859-1")
fake
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Yearâ...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obamaâs Na...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied âSafe Zoneâ Plan ...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 0      Donald Trump just couldn t wish all Americans ...         News
# 1      House Intelligence Committee Chairman Devin Nu...         News
# ...

# %%
true["label"]=1
fake["label"]=0

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Yearâ...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obamaâs Na...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
true.isna().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
fake.isna().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news=pd.concat([fake,true],axis=0)
news
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Yearâ...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obamaâs Na...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 0      Donald Trump just couldn t wish all Americans ...       News
# 1      House Intelligence Committee Chairman Devin Nu...       News
# 2      On Friday, it was revealed that former Milwauk...       News
# ...

# %%
news.dtypes
# Out:
# title      object
# text       object
# subject    object
# date       object
# label       int64
# dtype: object

# %%
news=news.drop(["title","subject","date"],axis=1)
news
# Out:
#                                                     text  label
# 0      Donald Trump just couldn t wish all Americans ...      0
# 1      House Intelligence Committee Chairman Devin Nu...      0
# 2      On Friday, it was revealed that former Milwauk...      0
# 3      On Christmas day, Donald Trump announced that ...      0
# 4      Pope Francis used his annual Christmas Day mes...      0
# ...                                                  ...    ...
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...      1
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...      1
# 21414  MINSK (Reuters) - In the shadow of disused Sov...      1
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...      1
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...      1
#
# [44898 rows x 2 columns]

# %%
news=news.sample(frac=1)
news
# Out:
#                                                     text  label
# 6464   Now that the side-show is essentially over and...      0
# 3946   WASHINGTON (Reuters) - Democrats in the U.S. H...      1
# 15600  DHAKA (Reuters) - Bangladeshi counter-terroris...      1
# 2184   According to Senator John McCain, Donald Trump...      0
# 5149   The fallout from the sexual harassment scandal...      0
# ...                                                  ...    ...
# 13505  Obama released a statement on his position reg...      0
# 8196    (This version of the Sep. 11 story corrects t...      1
# 12051  ASUNCION (Reuters) - Paraguayan Senator Mario ...      1
# 420    Donald Trump practically does something to cri...      0
# 20187  PRAGUE/WASHINGTON (Reuters) - Police and spy c...      1
#
# [44898 rows x 2 columns]

# %%
news=news.reset_index()

# %%
news.head()
# Out:
#    index                                               text  label
# 0   6464  Now that the side-show is essentially over and...      0
# 1   3946  WASHINGTON (Reuters) - Democrats in the U.S. H...      1
# 2  15600  DHAKA (Reuters) - Bangladeshi counter-terroris...      1
# 3   2184  According to Senator John McCain, Donald Trump...      0
# 4   5149  The fallout from the sexual harassment scandal...      0

# %%
news.drop(["index"],axis=1,inplace=True)

# %%
news
# Out:
#                                                     text  label
# 0      Now that the side-show is essentially over and...      0
# 1      WASHINGTON (Reuters) - Democrats in the U.S. H...      1
# 2      DHAKA (Reuters) - Bangladeshi counter-terroris...      1
# 3      According to Senator John McCain, Donald Trump...      0
# 4      The fallout from the sexual harassment scandal...      0
# ...                                                  ...    ...
# 44893  Obama released a statement on his position reg...      0
# 44894   (This version of the Sep. 11 story corrects t...      1
# 44895  ASUNCION (Reuters) - Paraguayan Senator Mario ...      1
# 44896  Donald Trump practically does something to cri...      0
# 44897  PRAGUE/WASHINGTON (Reuters) - Police and spy c...      1
#
# [44898 rows x 2 columns]

# %%
text=news.text
text
# Out:
# 0        Now that the side-show is essentially over and...
# 1        WASHINGTON (Reuters) - Democrats in the U.S. H...
# 2        DHAKA (Reuters) - Bangladeshi counter-terroris...
# 3        According to Senator John McCain, Donald Trump...
# 4        The fallout from the sexual harassment scandal...
#                                ...
# 44893    Obama released a statement on his position reg...
# 44894     (This version of the Sep. 11 story corrects t...
# 44895    ASUNCION (Reuters) - Paraguayan Senator Mario ...
# 44896    Donald Trump practically does something to cri...
# 44897    PRAGUE/WASHINGTON (Reuters) - Police and spy c...
# Name: text, Length: 44898, dtype: object

# %%
text=text.str.replace("[^a-zA-Z 0-9]","")
text
# Out:
# 0        Now that the side-show is essentially over and...
# 1        WASHINGTON (Reuters) - Democrats in the U.S. H...
# 2        DHAKA (Reuters) - Bangladeshi counter-terroris...
# 3        According to Senator John McCain, Donald Trump...
# 4        The fallout from the sexual harassment scandal...
#                                ...
# 44893    Obama released a statement on his position reg...
# 44894     (This version of the Sep. 11 story corrects t...
# 44895    ASUNCION (Reuters) - Paraguayan Senator Mario ...
# 44896    Donald Trump practically does something to cri...
# 44897    PRAGUE/WASHINGTON (Reuters) - Police and spy c...
# Name: text, Length: 44898, dtype: object

# %%
stemmer=SnowballStemmer("english")
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
text=text.apply(lambda row:[stemmer.stem(token.lower())for token in word_tokenize(row)]).apply(lambda token:" ".join(token))
text
# Out:
# 0        now that the side-show is essenti over and the...
# 1        washington ( reuter ) - democrat in the u.s. h...
# 2        dhaka ( reuter ) - bangladeshi counter-terror ...
# 3        accord to senat john mccain , donald trump s l...
# 4        the fallout from the sexual harass scandal inv...
#                                ...
# 44893    obama releas a statement on his posit regard t...
# 44894    ( this version of the sep. 11 stori correct th...
# 44895    asuncion ( reuter ) - paraguayan senat mario a...
# 44896    donald trump practic doe someth to critic the ...
# 44897    prague/washington ( reuter ) - polic and spi c...
# Name: text, Length: 44898, dtype: object

# %%
from nltk.corpus import stopwords
nltk.download("stopwords")
sw=stopwords.words("english")
text=text.apply(lambda row:[token for token in word_tokenize(row) if token not in sw]).apply(lambda token:" ".join(token))
text
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 0        lol ! want share everyon democrat convent sche...
# 1        washington ( reuter ) - two u.s. senat thursda...
# 2        mexico citi ( reuter ) - mexican prosecutor fa...
# 3        washington ( reuter ) - new u.s. commerc secre...
# 4        washington ( reuter ) - u.s. senat budget comm...
#                                ...
# 44893    beirut ( reuter ) - lebanon grand mufti , top ...
# 44894    tough imagin nascar race share donald trump ma...
# 44895    pari ( reuter ) - presid emmanuel macron said ...
# 44896    rex huppk , chicago tribun , exact known forma...
# 44897
# Name: text, Length: 44898, dtype: object

# %%
text=text.apply(lambda row:[token for token in word_tokenize(row) if len(token)>2]).apply(lambda token:" ".join(token))
text
# Out:
# 0        lol want share everyon democrat convent schedu...
# 1        washington reuter two u.s. senat thursday urg ...
# 2        mexico citi reuter mexican prosecutor fail sys...
# 3        washington reuter new u.s. commerc secretari w...
# 4        washington reuter u.s. senat budget committe t...
#                                ...
# 44893    beirut reuter lebanon grand mufti top cleric s...
# 44894    tough imagin nascar race share donald trump ma...
# 44895    pari reuter presid emmanuel macron said friday...
# 44896    rex huppk chicago tribun exact known formal re...
# 44897
# Name: text, Length: 44898, dtype: object

# %%
y=news["label"]
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 44893    1
# 44894    0
# 44895    1
# 44896    0
# 44897    0
# Name: label, Length: 44898, dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer=TfidfVectorizer()
data=vectorizer.fit_transform(text)
print(data)
# Out:
#   (0, 63892)	0.05006630834314984
#   (0, 62248)	0.059937645606061456
#   (0, 17269)	0.026153407017739737
#   (0, 71527)	0.03234024376901572
#   (0, 73123)	0.020783632878901642
#   (0, 16559)	0.08860815349209408
#   (0, 56259)	0.02664572341083481
#   (0, 43306)	0.027898470835310878
#   (0, 93022)	0.030997889326842342
#   (0, 82926)	0.03973480692927763
#   (0, 108624)	0.04133981744317642
#   (0, 83100)	0.06803139435582448
#   (0, 81617)	0.03310436786596769
#   (0, 94746)	0.044963851434812636
#   (0, 23859)	0.07805821482170555
#   (0, 71538)	0.03040168228179672
#   (0, 11940)	0.02723496240079966
#   (0, 24700)	0.08860815349209408
#   (0, 48126)	0.030317042698200288
#   (0, 29428)	0.025650010144691968
#   (0, 17182)	0.02901558895154872
#   (0, 79653)	0.045625328709741675
#   (0, 20847)	0.038956357128660135
#   (0, 89791)	0.02894967465668612
#   (0, 89801)	0.04317460448558829
#   :	:
#   (44896, 97498)	0.05129567923299368
#   (44896, 43110)	0.030531836447197473
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(data,y,test_size=0.3,random_state=1)

# %% [markdown]
# Model Training

# %%
nb=MultinomialNB()
dt=DecisionTreeClassifier(criterion="entropy",random_state=1,max_depth=4)
rf=RandomForestClassifier(random_state=1)
ab=AdaBoostClassifier(random_state=1)
models=[nb,dt,rf,ab]
for model in models:
  print(model)
  model.fit(X_train,y_train)

  y_pred=model.predict(X_test)
  print(classification_report(y_test,y_pred))
# Out:
# MultinomialNB()
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      7027
#            1       0.96      0.96      0.96      6443
#
#     accuracy                           0.96     13470
#    macro avg       0.96      0.96      0.96     13470
# weighted avg       0.96      0.96      0.96     13470
#
# DecisionTreeClassifier(criterion='entropy', max_depth=4, random_state=1)
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7027
#            1       1.00      1.00      1.00      6443
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470
#
# RandomForestClassifier(random_state=1)
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7027
#            1       1.00      1.00      1.00      6443
#
# ...
